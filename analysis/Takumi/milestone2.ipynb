# %% [markdown]
# ## Milestone 2
# * This is **Tak's** milestone2 notebook
#
# * Work for milestone2 will be done here
# Work for some EDAs and Task3 step 1-2 are done here
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/takumi/Documents/DATA301_1023/course-project-group_1023/data/raw/weatherAUS.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-646b562f7419> in <module>
# ----> 1 df = pd.read_csv('/Users/takumi/Documents/DATA301_1023/course-project-group_1023/data/raw/weatherAUS.csv')
#       2 df.head()
#
# ...

# %%
import pandas_profiling as pdp

profile_Aus = pdp.ProfileReport(df)

profile_Aus

# %%
### Dropping columns evaporation and sunshine beucase 40% are NA values. 

df2= df.drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])

df2

# %%
### changing column name rainfall to percipitation 
df3 = df2.rename(columns={'Rainfall':"Percipitation"})

df3

# %%
df4 = df3.dropna()
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c6d979aafa89> in <module>
# ----> 1 df4 = df3.dropna()
#       2 df4
#
# NameError: name 'df3' is not defined

# %%
df5 = df4.reset_index(drop=True)

df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dbfa505a4ea7> in <module>
# ----> 1 df5 = df4.reset_index(drop=True)
#       2
#       3 df5
#
# NameError: name 'df4' is not defined

# %% [markdown]
# ### Chain

# %%
df_chain= (
    pd.read_csv('/Users/takumi/Documents/DATA301_1023/course-project-group_1023/data/raw/weatherAUS.csv')
    .drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])
    .rename(columns={'Rainfall':"Percipitation"})
    .dropna()
    .reset_index(drop=True)
)

df_chain
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f1eaf6fdaffa> in <module>
#       1 df_chain= (
# ----> 2     pd.read_csv('/Users/takumi/Documents/DATA301_1023/course-project-group_1023/data/raw/weatherAUS.csv')
#       3     .drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])
#       4     .rename(columns={'Rainfall':"Percipitation"})
#       5     .dropna()
#
# ...

# %% [markdown]
# ## Creating a Funciton

# %%
def load_and_process(url_or_path_to_csv_file):
    #Chain 1 
        df1 = (
                pd.read_csv(url_or_path_to_csv_file)
                .drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])
                .rename(columns={'Rainfall':"Percipitation"})
                .dropna()
                .reset_index(drop=True)
        
            
            
        return df1
# Out:
#   File "<ipython-input-6-0fbc23e3e076>", line 12
#     return df1
#          ^
# SyntaxError: invalid syntax

# %%
def load_and_process(url_or_path_to_csv_file):

    # Method Chain 1 (Load data and deal with missing data)

    df1 = (
          pd.read_csv(url_or_path_to_csv_file)
          .drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])
          .rename(columns={'Rainfall':"Percipitation"})
          .dropna()
          .reset_index(drop=True))
        
    
    return df1

# %%
def load_and_process(url_or_path_to_csv_file):

    # Method Chain 1 (Load data and deal with missing data)

    df1 = (
          pd.read_csv(url_or_path_to_csv_file)
          .drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm','RainToday','RainTomorrow'])
          .rename(columns={'Rainfall':"Percipitation"})
          .dropna()
          
      )

    # Method Chain 2 (Resetting index)

    df2 = (
          df1
          .reset_index(drop=True)
      )

    # Make sure to return the latest dataframe

    return df2

# %%
load_and_process('/Users/takumi/Documents/DATA301_1023/course-project-group_1023/data/raw/weatherAUS.csv')
# Out:
#               Date Location  MinTemp  MaxTemp  Percipitation WindGustDir  \
# 0       2008-12-01   Albury     13.4     22.9            0.6           W
# 1       2008-12-02   Albury      7.4     25.1            0.0         WNW
# 2       2008-12-03   Albury     12.9     25.7            0.0         WSW
# 3       2008-12-04   Albury      9.2     28.0            0.0          NE
# 4       2008-12-05   Albury     17.5     32.3            1.0           W
# ...            ...      ...      ...      ...            ...         ...
# 113674  2017-06-20    Uluru      3.5     21.8            0.0           E
# 113675  2017-06-21    Uluru      2.8     23.4            0.0           E
# 113676  2017-06-22    Uluru      3.6     25.3            0.0         NNW
# 113677  2017-06-23    Uluru      5.4     26.9            0.0           N
# 113678  2017-06-24    Uluru      7.8     27.0            0.0          SE
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %% [markdown]
# ---
# ## Plot Analysis

# %%
### plotting frequency in wind direction observed at 9am 
plot_wind_count9am = sns.countplot(data=df,
                                   x= 'WindDir9am',
                                   order = ['N',"NNE","NE","E","ESE","SE","SSE","S","SSW","SW","WSW","W","WNW","NW","NNW"])

# %%
### plotting frequency in wind direction observed at 3pm 
plot_wind_count_3pm = sns.countplot(data=df,
                                    x='WindDir3pm',
                                    order = ['N',"NNE","NE","E","ESE","SE","SSE","S","SSW","SW","WSW","W","WNW","NW","NNW"])

# %%
### subsetting city of Sydney

sydney = df[df["Location"]=='Sydney']
sydney.head(10)
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 30176  2008-02-01   Sydney     19.5     22.4      15.6          6.2       0.0
# 30177  2008-02-02   Sydney     19.5     25.6       6.0          3.4       2.7
# 30178  2008-02-03   Sydney     21.6     24.5       6.6          2.4       0.1
# 30179  2008-02-04   Sydney     20.2     22.8      18.8          2.2       0.0
# 30180  2008-02-05   Sydney     19.7     25.7      77.4          NaN       0.0
# 30181  2008-02-06   Sydney     20.2     27.2       1.6          2.6       8.6
# 30182  2008-02-07   Sydney     18.6     26.3       6.2          5.2       5.2
# 30183  2008-02-08   Sydney     17.2     22.3      27.6          5.8       2.1
# 30184  2008-02-09   Sydney     16.4     20.8      12.6          4.8       3.0
# 30185  2008-02-10   Sydney     14.6     24.2       8.8          4.4      10.1
#
#       WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# ...

# %%
sydney.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
plot_sydney = sns.displot(data=sydney,
                         x='Date',
                         y= "Temp3pm",
                         aspect = 2)

# %%
import matplotlib.pyplot as plt
plot_sydney = sns.relplot(x='Date',
                         y= "Temp3pm",
                         data=sydney,
                         aspect = 2)

# %%
regres = sns.regplot(x="Date", y="Temp3pm", data=sydney)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-23-ec4568b49173> in <module>
# ----> 1 regres = sns.regplot(x="Date", y="Temp3pm", data=sydney)
#
# /opt/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/miniconda3/lib/python3.8/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
plot_sydney = sns.relplot(x='Date',
                         y= "Rainfall",
                         data=sydney,
                         aspect = 2)

# %%
#sydney['month_of_date'] = sydney['Date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-86609c323c83> in <module>
# ----> 1 sydney['month_of_date'] = sydney['Date'].dt.month
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...
